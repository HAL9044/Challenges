# %%
import pandas as pd

# %%
df = pd.read_csv('./data/input/IMDB-Movie-Data.csv')

# %%
def vote_counter(votes):
    if votes < 999:
        return 1
    elif votes >= 1000 and votes < 9999:
        return 2
    elif votes >= 10000 and votes < 99999:
        return 3
    elif votes >= 100000 and votes < 999999:
        return 4
    elif votes > 1000000:
        return 5

# %%
df.loc[:,"Votes"]
# Out:
# 0      757074
# 1      485820
# 2      157606
# 3       60545
# 4      393727
#         ...
# 995     27585
# 996     73152
# 997     70699
# 998      4881
# 999     12435
# Name: Votes, Length: 1000, dtype: int64

# %%
df["Bins"] = df["Votes"].apply(vote_counter)
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
def rvn_min (rev):
    return rev[0] / rev[1]

# %%
df['Rvn_Min'] = df[["Revenue (Millions)", "Runtime (Minutes)"]].apply(rvn_min, axis=1)

# %%
def rvn_min (rev, min):
    return rev / min

# %%
df['Rvn_Min'] = df.apply(lambda x: rvn_min(x["Revenue (Millions)"], x["Runtime (Minutes)"]), axis=1 )

# %%
def Trueif (str, rank):
    if "Thriller" in str:
        return rank + 1
    elif "Comedy" in str:
        return rank -1
    else: return rank

# %%
df["NewRanking"] = df.apply(lambda x: Trueif(x["Genre"], x["Rating"]), axis = 1)

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#Challenge 4
def ASCII (str, votes):
    sum = 0
    
    for char in str:
        sum = sum + ord(char)
    
    int_div = int(sum/votes)
    
    if int_div == 1:
        return True
    elif sum < votes:
        return False
    else: 
        for i in range (2, int_div - 1):
            if int_div % i == 0:
                return False
            else: 
                return True

# %%
df["Prime?"] = df.apply(lambda x: ASCII(x["Title"], x["Votes"]), axis = 1)

# %%
#How many millions did it cost to add one point to the average rating for each movie? 
#Not really statistically valid but still fun

# %%
def Rvn_Rank (rvn, rank, meta):
    avg = (rank + (meta/10)) / 2
    sc = rvn / avg
    return sc

# %%
df["Avg_Sc"] = df.apply(lambda x: Rvn_Rank(x["Revenue (Millions)"], x["Rating"], x["Metascore"]), axis = 1)
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...
